# %% [markdown]
# Indoor Scene Classification with TFLu and the ESP32-CAM

# %%
# %tensorflow_version 2.x
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %% [markdown]
# Python libraries

# %%
import numpy as np
import pathlib
import tensorflow as tf
import tensorflow_datasets as tfds
import zipfile
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2
from tensorflow.keras.models import Model

# %% [markdown]
# Constants

# %%
MODEL_ALPHA = 0.35
MODEL_INPUT_WIDTH = 48
MODEL_INPUT_HEIGHT = 48
TFL_MODEL_FILE = "indoor_scene_recognition.tflite"
TFL_MODEL_HEADER_FILE = "indoor_scene_recognition_model.h"
TF_MODEL = "indoor_scene_recognition"

# %% [markdown]
# Transfer learning with Keras
#
# Unzip the dataset (dataset.zip)

# %%
import zipfile
with zipfile.ZipFile("dataset.zip", 'r') as zip_ref:
  zip_ref.extractall(".")
data_dir = "dataset"

# %% [markdown]
# Prepare the train (80%) and validation (20%) datasets

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  interpolation="bilinear",
  image_size=(48, 48))
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  interpolation="bilinear",
  image_size=(48, 48))
# Out:
# Found 43 files belonging to 3 classes.
# Using 35 files for training.
# Found 43 files belonging to 3 classes.
# Using 8 files for validation.

# %% [markdown]
# Get the name of the classes

# %%
class_names = train_ds.class_names
num_classes = len(class_names)
print(class_names)
# Out:
# ['Glass', 'Mag', 'Unknown']

# %% [markdown]
# Rescale the pixel values from [0, 255] tp [-1, 1]

# %%
rescale = tf.keras.layers.Rescaling(1./255, offset= -1)
train_ds = train_ds.map(lambda x, y: (rescale(x), y))
val_ds   = val_ds.map(lambda x, y: (rescale(x), y))

# %% [markdown]
# Import the MobileNet v2 pre-trained model

# %%
# https://github.com/keras-team/keras-applications/blob/master/keras_applications/mobilenet_v2.py
base_model = MobileNetV2(input_shape=(MODEL_INPUT_WIDTH, MODEL_INPUT_HEIGHT, 3),
                         include_top=False,
                         weights='imagenet',
                         alpha=0.35)
base_model.trainable = False

feat_extr = base_model
# Out:
# /tmp/ipython-input-3994110907.py:2: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(input_shape=(MODEL_INPUT_WIDTH, MODEL_INPUT_HEIGHT, 3),
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_0.35_224_no_top.h5
# 2019640/2019640 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# Augment the input data

# %%
augmen = tf.keras.Sequential([
  tf.keras.layers.RandomRotation(0.2),
  tf.keras.layers.RandomFlip('horizontal'),
])

train_ds = train_ds.map(lambda x, y: (augmen(x), y))
val_ds   = val_ds.map(lambda x, y: (augmen(x), y))

# %% [markdown]
# Prepare the classification head

# %%
global_avg_layer = tf.keras.layers.GlobalAveragePooling2D()
dense_layer = tf.keras.layers.Dense(num_classes, activation='softmax')

# %% [markdown]
# Build the model architecture

# %%
inputs = tf.keras.Input(shape=(MODEL_INPUT_WIDTH, MODEL_INPUT_HEIGHT, 3))
x = global_avg_layer(feat_extr.layers[-1].output)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = dense_layer(x)
model = tf.keras.Model(inputs=feat_extr.inputs, outputs=outputs)

# %% [markdown]
# Compile the model with a 0.0005 learning rate

# %%
lr = 0.0005
model.compile(
  optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=False),
  metrics=['accuracy'])

# %% [markdown]
# Model summary

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 48, 48, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 24, 24,    │        432 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 24, 24,    │         64 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1_relu (ReLU)   │ (None, 24, 24,    │          0 │ bn_Conv1[0][0]    │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 24, 24,    │        144 │ Conv1_relu[0][0]  │
# │ (DepthwiseConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 24, 24,    │         64 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 24, 24,    │          0 │ expanded_conv_de… │
# │ (ReLU)              │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 24, 24, 8) │        128 │ expanded_conv_de… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 24, 24, 8) │         32 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand      │ (None, 24, 24,    │        384 │ expanded_conv_pr… │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_BN   │ (None, 24, 24,    │        192 │ block_1_expand[0… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_relu │ (None, 24, 24,    │          0 │ block_1_expand_B… │
# │ (ReLU)              │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_pad         │ (None, 25, 25,    │          0 │ block_1_expand_r… │
# │ (ZeroPadding2D)     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise   │ (None, 12, 12,    │        432 │ block_1_pad[0][0] │
# │ (DepthwiseConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 12, 12,    │        192 │ block_1_depthwis… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 12, 12,    │          0 │ block_1_depthwis… │
# │ (ReLU)              │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project     │ (None, 12, 12, 8) │        384 │ block_1_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project_BN  │ (None, 12, 12, 8) │         32 │ block_1_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand      │ (None, 12, 12,    │        384 │ block_1_project_… │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_BN   │ (None, 12, 12,    │        192 │ block_2_expand[0… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_relu │ (None, 12, 12,    │          0 │ block_2_expand_B… │
# │ (ReLU)              │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise   │ (None, 12, 12,    │        432 │ block_2_expand_r… │
# │ (DepthwiseConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 12, 12,    │        192 │ block_2_depthwis… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 12, 12,    │          0 │ block_2_depthwis… │
# │ (ReLU)              │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project     │ (None, 12, 12, 8) │        384 │ block_2_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project_BN  │ (None, 12, 12, 8) │         32 │ block_2_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_add (Add)   │ (None, 12, 12, 8) │          0 │ block_1_project_… │
# │                     │                   │            │ block_2_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand      │ (None, 12, 12,    │        384 │ block_2_add[0][0] │
# │ (Conv2D)            │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_BN   │ (None, 12, 12,    │        192 │ block_3_expand[0… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_relu │ (None, 12, 12,    │          0 │ block_3_expand_B… │
# │ (ReLU)              │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_pad         │ (None, 13, 13,    │          0 │ block_3_expand_r… │
# │ (ZeroPadding2D)     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise   │ (None, 6, 6, 48)  │        432 │ block_3_pad[0][0] │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 6, 6, 48)  │        192 │ block_3_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 6, 6, 48)  │          0 │ block_3_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project     │ (None, 6, 6, 16)  │        768 │ block_3_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project_BN  │ (None, 6, 6, 16)  │         64 │ block_3_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand      │ (None, 6, 6, 96)  │      1,536 │ block_3_project_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_BN   │ (None, 6, 6, 96)  │        384 │ block_4_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_relu │ (None, 6, 6, 96)  │          0 │ block_4_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise   │ (None, 6, 6, 96)  │        864 │ block_4_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 6, 6, 96)  │        384 │ block_4_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 6, 6, 96)  │          0 │ block_4_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project     │ (None, 6, 6, 16)  │      1,536 │ block_4_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project_BN  │ (None, 6, 6, 16)  │         64 │ block_4_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_add (Add)   │ (None, 6, 6, 16)  │          0 │ block_3_project_… │
# │                     │                   │            │ block_4_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand      │ (None, 6, 6, 96)  │      1,536 │ block_4_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_BN   │ (None, 6, 6, 96)  │        384 │ block_5_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_relu │ (None, 6, 6, 96)  │          0 │ block_5_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise   │ (None, 6, 6, 96)  │        864 │ block_5_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 6, 6, 96)  │        384 │ block_5_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 6, 6, 96)  │          0 │ block_5_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project     │ (None, 6, 6, 16)  │      1,536 │ block_5_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project_BN  │ (None, 6, 6, 16)  │         64 │ block_5_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_add (Add)   │ (None, 6, 6, 16)  │          0 │ block_4_add[0][0… │
# │                     │                   │            │ block_5_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand      │ (None, 6, 6, 96)  │      1,536 │ block_5_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_BN   │ (None, 6, 6, 96)  │        384 │ block_6_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_relu │ (None, 6, 6, 96)  │          0 │ block_6_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_pad         │ (None, 7, 7, 96)  │          0 │ block_6_expand_r… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise   │ (None, 3, 3, 96)  │        864 │ block_6_pad[0][0] │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 3, 3, 96)  │        384 │ block_6_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 3, 3, 96)  │          0 │ block_6_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project     │ (None, 3, 3, 24)  │      2,304 │ block_6_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project_BN  │ (None, 3, 3, 24)  │         96 │ block_6_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand      │ (None, 3, 3, 144) │      3,456 │ block_6_project_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_BN   │ (None, 3, 3, 144) │        576 │ block_7_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_relu │ (None, 3, 3, 144) │          0 │ block_7_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise   │ (None, 3, 3, 144) │      1,296 │ block_7_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 3, 3, 144) │        576 │ block_7_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 3, 3, 144) │          0 │ block_7_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project     │ (None, 3, 3, 24)  │      3,456 │ block_7_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project_BN  │ (None, 3, 3, 24)  │         96 │ block_7_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_add (Add)   │ (None, 3, 3, 24)  │          0 │ block_6_project_… │
# │                     │                   │            │ block_7_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand      │ (None, 3, 3, 144) │      3,456 │ block_7_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_BN   │ (None, 3, 3, 144) │        576 │ block_8_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_relu │ (None, 3, 3, 144) │          0 │ block_8_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise   │ (None, 3, 3, 144) │      1,296 │ block_8_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 3, 3, 144) │        576 │ block_8_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 3, 3, 144) │          0 │ block_8_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project     │ (None, 3, 3, 24)  │      3,456 │ block_8_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project_BN  │ (None, 3, 3, 24)  │         96 │ block_8_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_add (Add)   │ (None, 3, 3, 24)  │          0 │ block_7_add[0][0… │
# │                     │                   │            │ block_8_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand      │ (None, 3, 3, 144) │      3,456 │ block_8_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_BN   │ (None, 3, 3, 144) │        576 │ block_9_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_relu │ (None, 3, 3, 144) │          0 │ block_9_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise   │ (None, 3, 3, 144) │      1,296 │ block_9_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 3, 3, 144) │        576 │ block_9_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 3, 3, 144) │          0 │ block_9_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project     │ (None, 3, 3, 24)  │      3,456 │ block_9_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project_BN  │ (None, 3, 3, 24)  │         96 │ block_9_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_add (Add)   │ (None, 3, 3, 24)  │          0 │ block_8_add[0][0… │
# │                     │                   │            │ block_9_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand     │ (None, 3, 3, 144) │      3,456 │ block_9_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_BN  │ (None, 3, 3, 144) │        576 │ block_10_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_re… │ (None, 3, 3, 144) │          0 │ block_10_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise  │ (None, 3, 3, 144) │      1,296 │ block_10_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 3, 3, 144) │        576 │ block_10_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 3, 3, 144) │          0 │ block_10_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project    │ (None, 3, 3, 32)  │      4,608 │ block_10_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project_BN │ (None, 3, 3, 32)  │        128 │ block_10_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand     │ (None, 3, 3, 192) │      6,144 │ block_10_project… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_BN  │ (None, 3, 3, 192) │        768 │ block_11_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_re… │ (None, 3, 3, 192) │          0 │ block_11_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise  │ (None, 3, 3, 192) │      1,728 │ block_11_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 3, 3, 192) │        768 │ block_11_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 3, 3, 192) │          0 │ block_11_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project    │ (None, 3, 3, 32)  │      6,144 │ block_11_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project_BN │ (None, 3, 3, 32)  │        128 │ block_11_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_add (Add)  │ (None, 3, 3, 32)  │          0 │ block_10_project… │
# │                     │                   │            │ block_11_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand     │ (None, 3, 3, 192) │      6,144 │ block_11_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_BN  │ (None, 3, 3, 192) │        768 │ block_12_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_re… │ (None, 3, 3, 192) │          0 │ block_12_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise  │ (None, 3, 3, 192) │      1,728 │ block_12_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 3, 3, 192) │        768 │ block_12_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 3, 3, 192) │          0 │ block_12_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project    │ (None, 3, 3, 32)  │      6,144 │ block_12_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project_BN │ (None, 3, 3, 32)  │        128 │ block_12_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_add (Add)  │ (None, 3, 3, 32)  │          0 │ block_11_add[0][… │
# │                     │                   │            │ block_12_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand     │ (None, 3, 3, 192) │      6,144 │ block_12_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_BN  │ (None, 3, 3, 192) │        768 │ block_13_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_re… │ (None, 3, 3, 192) │          0 │ block_13_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_pad        │ (None, 5, 5, 192) │          0 │ block_13_expand_… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise  │ (None, 2, 2, 192) │      1,728 │ block_13_pad[0][… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 2, 2, 192) │        768 │ block_13_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 2, 2, 192) │          0 │ block_13_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project    │ (None, 2, 2, 56)  │     10,752 │ block_13_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project_BN │ (None, 2, 2, 56)  │        224 │ block_13_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand     │ (None, 2, 2, 336) │     18,816 │ block_13_project… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_BN  │ (None, 2, 2, 336) │      1,344 │ block_14_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_re… │ (None, 2, 2, 336) │          0 │ block_14_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise  │ (None, 2, 2, 336) │      3,024 │ block_14_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 2, 2, 336) │      1,344 │ block_14_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 2, 2, 336) │          0 │ block_14_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project    │ (None, 2, 2, 56)  │     18,816 │ block_14_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project_BN │ (None, 2, 2, 56)  │        224 │ block_14_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_add (Add)  │ (None, 2, 2, 56)  │          0 │ block_13_project… │
# │                     │                   │            │ block_14_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand     │ (None, 2, 2, 336) │     18,816 │ block_14_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_BN  │ (None, 2, 2, 336) │      1,344 │ block_15_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_re… │ (None, 2, 2, 336) │          0 │ block_15_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise  │ (None, 2, 2, 336) │      3,024 │ block_15_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 2, 2, 336) │      1,344 │ block_15_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 2, 2, 336) │          0 │ block_15_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project    │ (None, 2, 2, 56)  │     18,816 │ block_15_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project_BN │ (None, 2, 2, 56)  │        224 │ block_15_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_add (Add)  │ (None, 2, 2, 56)  │          0 │ block_14_add[0][… │
# │                     │                   │            │ block_15_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand     │ (None, 2, 2, 336) │     18,816 │ block_15_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_BN  │ (None, 2, 2, 336) │      1,344 │ block_16_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_re… │ (None, 2, 2, 336) │          0 │ block_16_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise  │ (None, 2, 2, 336) │      3,024 │ block_16_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 2, 2, 336) │      1,344 │ block_16_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 2, 2, 336) │          0 │ block_16_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project    │ (None, 2, 2, 112) │     37,632 │ block_16_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project_BN │ (None, 2, 2, 112) │        448 │ block_16_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1 (Conv2D)     │ (None, 2, 2,      │    143,360 │ block_16_project… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1_bn           │ (None, 2, 2,      │      5,120 │ Conv_1[0][0]      │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_relu (ReLU)     │ (None, 2, 2,      │          0 │ Conv_1_bn[0][0]   │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ out_relu[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 1280)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 3)         │      3,843 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 414,051 (1.58 MB)
#  Trainable params: 3,843 (15.01 KB)
#  Non-trainable params: 410,208 (1.56 MB)

# %% [markdown]
# Train the model with 100 epochs

# %%
model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=100
)
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.5580 - loss: 0.9213 - val_accuracy: 0.6250 - val_loss: 0.7558
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 337ms/step - accuracy: 0.6863 - loss: 0.8321 - val_accuracy: 0.7500 - val_loss: 0.7419
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 352ms/step - accuracy: 0.6274 - loss: 0.8553 - val_accuracy: 0.6250 - val_loss: 0.9718
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 332ms/step - accuracy: 0.6568 - loss: 0.9328 - val_accuracy: 0.2500 - val_loss: 1.0478
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 357ms/step - accuracy: 0.5979 - loss: 0.7042 - val_accuracy: 0.6250 - val_loss: 0.7903
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 242ms/step - accuracy: 0.8527 - loss: 0.6008 - val_accuracy: 0.5000 - val_loss: 0.9382
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.7158 - loss: 0.6916 - val_accuracy: 0.7500 - val_loss: 0.6728
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.7348 - loss: 0.6666 - val_accuracy: 0.6250 - val_loss: 0.8332
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 230ms/step - accuracy: 0.7262 - loss: 0.7148 - val_accuracy: 0.8750 - val_loss: 0.4610
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.7158 - loss: 0.6270 - val_accuracy: 0.8750 - val_loss: 0.5177
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.7348 - loss: 0.6800 - val_accuracy: 0.7500 - val_loss: 0.4604
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.7643 - loss: 0.5609 - val_accuracy: 0.8750 - val_loss: 0.4945
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.7054 - loss: 0.6245 - val_accuracy: 0.7500 - val_loss: 0.7220
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.6863 - loss: 0.6085 - val_accuracy: 0.8750 - val_loss: 0.5792
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.8232 - loss: 0.4750 - val_accuracy: 0.7500 - val_loss: 0.4523
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.8336 - loss: 0.5693 - val_accuracy: 0.8750 - val_loss: 0.6585
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.7452 - loss: 0.5555 - val_accuracy: 0.7500 - val_loss: 0.6713
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.8336 - loss: 0.5166 - val_accuracy: 0.8750 - val_loss: 0.5459
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.7452 - loss: 0.4516 - val_accuracy: 0.7500 - val_loss: 0.6290
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.8146 - loss: 0.3958 - val_accuracy: 1.0000 - val_loss: 0.2675
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.8821 - loss: 0.3527 - val_accuracy: 0.8750 - val_loss: 0.5072
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9116 - loss: 0.3239 - val_accuracy: 0.7500 - val_loss: 0.4519
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.9116 - loss: 0.3770 - val_accuracy: 0.7500 - val_loss: 0.5286
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.9411 - loss: 0.3593 - val_accuracy: 1.0000 - val_loss: 0.3213
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.8926 - loss: 0.4331 - val_accuracy: 0.8750 - val_loss: 0.3843
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.8821 - loss: 0.3643 - val_accuracy: 0.7500 - val_loss: 0.4738
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.8821 - loss: 0.4056 - val_accuracy: 0.8750 - val_loss: 0.2324
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9116 - loss: 0.3964 - val_accuracy: 0.8750 - val_loss: 0.3838
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.9116 - loss: 0.3772 - val_accuracy: 0.6250 - val_loss: 0.8249
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - accuracy: 0.9116 - loss: 0.3533 - val_accuracy: 1.0000 - val_loss: 0.3110
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9515 - loss: 0.3439 - val_accuracy: 0.6250 - val_loss: 0.6244
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.8527 - loss: 0.4123 - val_accuracy: 0.8750 - val_loss: 0.3069
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9116 - loss: 0.3664 - val_accuracy: 1.0000 - val_loss: 0.2521
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 347ms/step - accuracy: 0.9705 - loss: 0.3142 - val_accuracy: 1.0000 - val_loss: 0.2308
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 319ms/step - accuracy: 0.9116 - loss: 0.3742 - val_accuracy: 0.7500 - val_loss: 0.5087
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 368ms/step - accuracy: 0.9411 - loss: 0.3536 - val_accuracy: 1.0000 - val_loss: 0.2078
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 352ms/step - accuracy: 0.8232 - loss: 0.3737 - val_accuracy: 0.8750 - val_loss: 0.5465
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9705 - loss: 0.3092 - val_accuracy: 0.8750 - val_loss: 0.3741
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 204ms/step - accuracy: 0.9705 - loss: 0.2709 - val_accuracy: 0.8750 - val_loss: 0.4928
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.9705 - loss: 0.2608 - val_accuracy: 1.0000 - val_loss: 0.1110
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 209ms/step - accuracy: 0.9411 - loss: 0.2852 - val_accuracy: 1.0000 - val_loss: 0.2111
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9116 - loss: 0.3183 - val_accuracy: 0.8750 - val_loss: 0.4228
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.9411 - loss: 0.2461 - val_accuracy: 1.0000 - val_loss: 0.2397
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 1.0000 - loss: 0.2044 - val_accuracy: 0.8750 - val_loss: 0.2635
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.9705 - loss: 0.2395 - val_accuracy: 0.6250 - val_loss: 0.5865
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9220 - loss: 0.3715 - val_accuracy: 1.0000 - val_loss: 0.1679
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 211ms/step - accuracy: 0.9705 - loss: 0.2834 - val_accuracy: 1.0000 - val_loss: 0.2361
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.9411 - loss: 0.2346 - val_accuracy: 0.8750 - val_loss: 0.5251
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.9705 - loss: 0.2406 - val_accuracy: 0.8750 - val_loss: 0.3984
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9411 - loss: 0.2422 - val_accuracy: 1.0000 - val_loss: 0.2170
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.9411 - loss: 0.2634 - val_accuracy: 1.0000 - val_loss: 0.2337
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.9705 - loss: 0.2027 - val_accuracy: 0.8750 - val_loss: 0.3176
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9220 - loss: 0.2426 - val_accuracy: 0.8750 - val_loss: 0.2356
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 1.0000 - loss: 0.1674 - val_accuracy: 0.8750 - val_loss: 0.3657
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 271ms/step - accuracy: 1.0000 - loss: 0.2411 - val_accuracy: 1.0000 - val_loss: 0.1982
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 1.0000 - loss: 0.2022 - val_accuracy: 1.0000 - val_loss: 0.2243
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.9705 - loss: 0.1988 - val_accuracy: 0.8750 - val_loss: 0.3455
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9411 - loss: 0.2252 - val_accuracy: 1.0000 - val_loss: 0.0791
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.8821 - loss: 0.3124 - val_accuracy: 1.0000 - val_loss: 0.1152
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.8821 - loss: 0.2636 - val_accuracy: 0.8750 - val_loss: 0.5111
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.9411 - loss: 0.2161 - val_accuracy: 0.8750 - val_loss: 0.2288
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.9705 - loss: 0.1930 - val_accuracy: 1.0000 - val_loss: 0.2536
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.9411 - loss: 0.2620 - val_accuracy: 0.8750 - val_loss: 0.1881
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 380ms/step - accuracy: 0.8527 - loss: 0.2848 - val_accuracy: 1.0000 - val_loss: 0.1666
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 347ms/step - accuracy: 1.0000 - loss: 0.1691 - val_accuracy: 1.0000 - val_loss: 0.2589
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 363ms/step - accuracy: 0.9705 - loss: 0.2551 - val_accuracy: 0.8750 - val_loss: 0.2865
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 297ms/step - accuracy: 0.9411 - loss: 0.2695 - val_accuracy: 0.8750 - val_loss: 0.4209
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 1.0000 - loss: 0.1816 - val_accuracy: 1.0000 - val_loss: 0.1973
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9705 - loss: 0.1801 - val_accuracy: 0.8750 - val_loss: 0.1766
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 1.0000 - loss: 0.1528 - val_accuracy: 1.0000 - val_loss: 0.1058
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 1.0000 - loss: 0.1919 - val_accuracy: 1.0000 - val_loss: 0.1275
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 1.0000 - loss: 0.1682 - val_accuracy: 1.0000 - val_loss: 0.1503
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 1.0000 - loss: 0.1411 - val_accuracy: 0.8750 - val_loss: 0.3309
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.9411 - loss: 0.2262 - val_accuracy: 1.0000 - val_loss: 0.1711
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9705 - loss: 0.1996 - val_accuracy: 0.8750 - val_loss: 0.1890
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9705 - loss: 0.1951 - val_accuracy: 0.8750 - val_loss: 0.3746
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 1.0000 - loss: 0.1980 - val_accuracy: 1.0000 - val_loss: 0.1700
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 1.0000 - loss: 0.2006 - val_accuracy: 1.0000 - val_loss: 0.2263
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.9411 - loss: 0.2532 - val_accuracy: 1.0000 - val_loss: 0.1524
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.9705 - loss: 0.1389 - val_accuracy: 1.0000 - val_loss: 0.1555
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 1.0000 - loss: 0.1526 - val_accuracy: 1.0000 - val_loss: 0.1697
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 1.0000 - loss: 0.1248 - val_accuracy: 1.0000 - val_loss: 0.1124
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 1.0000 - loss: 0.1349 - val_accuracy: 1.0000 - val_loss: 0.1127
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 1.0000 - loss: 0.1110 - val_accuracy: 0.8750 - val_loss: 0.2288
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 1.0000 - loss: 0.1278 - val_accuracy: 0.8750 - val_loss: 0.2002
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 1.0000 - loss: 0.1790 - val_accuracy: 1.0000 - val_loss: 0.0801
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - accuracy: 1.0000 - loss: 0.1740 - val_accuracy: 1.0000 - val_loss: 0.0896
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.9705 - loss: 0.1516 - val_accuracy: 1.0000 - val_loss: 0.2997
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9705 - loss: 0.1872 - val_accuracy: 1.0000 - val_loss: 0.1397
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9705 - loss: 0.1747 - val_accuracy: 0.6250 - val_loss: 0.5268
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 1.0000 - loss: 0.1717 - val_accuracy: 0.8750 - val_loss: 0.3911
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 1.0000 - loss: 0.1496 - val_accuracy: 1.0000 - val_loss: 0.0788
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9220 - loss: 0.2249 - val_accuracy: 1.0000 - val_loss: 0.1327
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 1.0000 - loss: 0.1656 - val_accuracy: 1.0000 - val_loss: 0.2353
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 369ms/step - accuracy: 1.0000 - loss: 0.1434 - val_accuracy: 1.0000 - val_loss: 0.0479
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 346ms/step - accuracy: 0.9705 - loss: 0.1585 - val_accuracy: 1.0000 - val_loss: 0.1051
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 340ms/step - accuracy: 0.9705 - loss: 0.1212 - val_accuracy: 1.0000 - val_loss: 0.1132
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 362ms/step - accuracy: 1.0000 - loss: 0.1455 - val_accuracy: 1.0000 - val_loss: 0.0497
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 344ms/step - accuracy: 1.0000 - loss: 0.1204 - val_accuracy: 1.0000 - val_loss: 0.0689
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 1.0000 - loss: 0.1431 - val_accuracy: 0.8750 - val_loss: 0.2971

# %% [markdown]
# Save the TensorFlow model

# %%
model.save("indoor_scene_recognition.keras")
model.export("indoor_scene_recognition")
model.save("indoor_scene_recognition.h5")
# Out:
# Saved artifact at 'indoor_scene_recognition'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): List[TensorSpec(shape=(None, 48, 48, 3), dtype=tf.float32, name='keras_tensor')]
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   139457976534800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976536720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976536336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976535376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976533840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976537296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976537872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976536912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976534992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976537680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976538256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976539792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976539984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976538832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976536144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976538640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976542288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976542480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976541328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976540752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976540176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976543632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976543824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976543056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976540944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976542672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976541136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976542096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976543248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976544784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976544208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976544400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976544592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976543440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976545744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976545168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976545360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976545552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976541520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976546704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976547088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976547280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976546320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976546896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976547856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976548240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976548432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976547472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976548048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976549008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976546512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976546128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976548816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976548624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976547664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976545936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977582992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977583184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457976549200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977582032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977581648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977582800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977582608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977582416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977584144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457980399248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977583760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977583952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977581840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977585104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977584528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977584720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977584912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977584336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977586064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977585488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977585680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977585872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977583376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977587024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977586448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977586640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977586832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977583568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977587984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977587408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977587600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977587792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977585296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977588944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977588368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977588560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977588752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977586256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977589904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977589328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977589520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977589712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977587216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977590864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977590288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977590480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977590672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977588176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977591824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977591248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977591440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977591632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977589136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977592784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977592208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977592400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977592592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977590096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977593744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977593168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977593360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977593552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977591056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977594704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977594128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977594320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977594512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977592016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977595664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977595088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977595280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977595472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977592976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977596624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977596048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977596240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977596432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977593936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977597584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977597008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977595856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977597392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977597200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977596816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977594896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978828176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978828368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457977597776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978827216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978826832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978827984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978827792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978827600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978829328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978828752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978828944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978829136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978827024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978830288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978829712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978829904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978830096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978827408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978831248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978830672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978830864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978831056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978828560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978832208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978831632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978831824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978832016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978829520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978833168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978832592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978832784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978832976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978830480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978834128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978833552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978833744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978833936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978831440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978835088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978834512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978834704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978834896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978832400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978836048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978835472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978835664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978835856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978833360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978837008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978836432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978836624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978836816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978834320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978837968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978837392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978837584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978837776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978835280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978838928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978838352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978838544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978838736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978836240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978839888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978839312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978839504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978839696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978837200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978840848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978840272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978840464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978840656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978838160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978841808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978841232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978841424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978841616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978839120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978842768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978842192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978841040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978842576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978842384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978842000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978840080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924874512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924874896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457978842960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924875856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924874320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924875472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924875664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924875280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924876816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924876240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924876432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924876624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924874704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924877776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924877200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924877392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924877584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924875088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924878736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924878160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924878352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924878544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924876048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924879696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924879120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924879312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924879504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924877008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924880656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924880080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924880272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924880464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924877968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924881616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924883344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457924884304: TensorSpec(shape=(), dtype=tf.resource, name=None)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# Preparing and testing the quantized TFLite model
#
# Unzip the test dataset (test_samples.zip)

# %%
with zipfile.ZipFile("test_samples.zip", 'r') as zip_ref:
    zip_ref.extractall(".")
test_dir = "test_samples"

# %% [markdown]
# Rescale the pixel values from [0, 255] to [-1, 1]

# %%
test_ds = tf.keras.utils.image_dataset_from_directory(test_dir,
                                                      interpolation="bilinear",
                                                      image_size=(MODEL_INPUT_WIDTH, MODEL_INPUT_HEIGHT))
test_ds  = test_ds.map(lambda x, y: (rescale(x), y))
# Out:
# Found 13 files belonging to 1 classes.

# %% [markdown]
# Quantize the TensorFlow model with the TFLite converter

# %%
repr_ds = test_ds.unbatch()

def representative_data_gen():
  for i_value, o_value in repr_ds.batch(1).take(48):
    yield [i_value]

converter = tf.lite.TFLiteConverter.from_saved_model(TF_MODEL)
converter.representative_dataset = tf.lite.RepresentativeDataset(representative_data_gen)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8

tfl_model = converter.convert()

# %% [markdown]
# Get the TFLite model size in bytes

# %%
size_tfl_model = len(tfl_model)
print(len(tfl_model), "bytes")
# Out:
# 619840 bytes

# %% [markdown]
# Initialize the TFLite interpreter

# %%
# Initialize the TFLite interpreter
interpreter = tf.lite.Interpreter(model_content=tfl_model)

# Allocate the tensors
interpreter.allocate_tensors()
# Out:
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)

# %% [markdown]
# Get input quantization parameters

# %%
# Get input/output layer information
i_details = interpreter.get_input_details()[0]
o_details = interpreter.get_output_details()[0]

# Get input quantization parameters.
i_quant = i_details["quantization_parameters"]
i_scale      = i_quant['scales'][0]
i_zero_point = i_quant['zero_points'][0]

# %% [markdown]
# Evaluate the accuracy of the quantized TFLite model

# %%
test_ds0 = val_ds.unbatch()

num_correct_samples = 0
num_total_samples   = len(list(test_ds0.batch(1)))

for i_value, o_value in test_ds0.batch(1):
  i_value = (i_value / i_scale) + i_zero_point
  i_value = tf.cast(i_value, dtype=tf.int8)
  interpreter.set_tensor(i_details["index"], i_value)
  interpreter.invoke()
  o_pred = interpreter.get_tensor(o_details["index"])[0]

  if np.argmax(o_pred) == o_value:
    num_correct_samples += 1

print("Accuracy:", num_correct_samples/num_total_samples)
# Out:
# Accuracy: 0.75

# %% [markdown]
# Convert the TFLite model to C-byte array with xxd

# %%
open("model.tflite", "wb").write(tfl_model)
# !apt-get update && apt-get -qq install xxd
# !xxd -c 60 -i model.tflite > indoor_scene_recognition.h
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [80.2 kB]
# Get:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:13 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,942 kB]
# Get:14 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,209 kB]
# Get:15 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,783 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,272 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,305 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,623 kB]
# Get:19 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [5,357 kB]
# Get:20 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [42.7 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [5,560 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,579 kB]
# Fetched 35.2 MB in 5s (7,483 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
